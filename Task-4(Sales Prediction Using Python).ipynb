# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
task_Advertising=pd.read_csv("/content/advertising.csv")

# %%
task_Advertising
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
task_Advertising.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
task_Advertising.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
task_Advertising.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
task_Advertising.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
task_Advertising.shape
# Out:
# (200, 4)

# %%
sns.scatterplot(x=task_Advertising.TV ,y=task_Advertising.Sales ,color='g')
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.scatterplot(x=task_Advertising.Newspaper ,y=task_Advertising.Sales ,color='orange')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
sns.lmplot(x='TV' , y='Sales',data=task_Advertising)
sns.lmplot(x='Radio' , y='Sales',data=task_Advertising)
sns.lmplot(x='Newspaper' , y='Sales',data=task_Advertising)

# %%
plt.figure(figsize=(12,6))
plt.subplot(221)
plt.hist(task_Advertising.TV ,color="pink")
plt.title("TV")
# Out:
# Text(0.5, 1.0, 'TV')

# %%
plt.figure(figsize=(12,6))
plt.subplot(221)
plt.hist(task_Advertising.TV ,color="g")
plt.title("TV")

plt.subplot(222)
plt.hist(task_Advertising.Radio ,color="b")
plt.title("Radio")

plt.subplot(223)
plt.hist(task_Advertising.Newspaper ,color="red")
plt.title("Newspaper")

plt.subplot(224)
plt.hist(task_Advertising.Sales ,color="black")
plt.title("Sales")
# Out:
# Text(0.5, 1.0, 'Sales')

# %%
sns.heatmap(task_Advertising.corr() , annot=True ,fmt='2f')
plt.title("Correlation of advertising mediums and sales")
# Out:
# Text(0.5, 1.0, 'Correlation of advertising mediums and sales')

# %%
x=task_Advertising[['TV']]
y=task_Advertising[['Sales']]

# %%
x_train, X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
print(x_train)
print(X_test)
print(y_train)
print(y_test)
# Out:
#         TV
# 134   36.9
# 66    31.5
# 26   142.9
# 113  209.6
# 168  215.4
# ..     ...
# 67   139.3
# 192   17.2
# 117   76.4
# 47   239.9
# 172   19.6
#
# [160 rows x 1 columns]
#         TV
# 18    69.2
# 170   50.0
# 107   90.4
# 98   289.7
# 177  170.2
# 182   56.2
# 5      8.7
# 146  240.1
# 12    23.8
# 152  197.6
# 61   261.3
# 125   87.2
# 180  156.6
# 154  187.8
# 80    76.4
# 7    120.2
# 33   265.6
# 130    0.7
# 37    74.7
# 74   213.4
# 183  287.6
# 145  140.3
# 45   175.1
# 159  131.7
# 60    53.5
# 123  123.1
# 179  165.6
# 185  205.0
# 122  224.0
# 44    25.1
# 16    67.8
# 55   198.9
# 150  280.7
# 111  241.7
# 22    13.2
# 189   18.7
# 129   59.6
# 4    180.8
# 83    68.4
# 106   25.0
#      Sales
# 134   10.8
# 66    11.0
# 26    15.0
# 113   20.9
# 168   17.1
# ..     ...
# 67    13.4
# 192    5.9
# 117    9.4
# 47    23.2
# 172    7.6
#
# [160 rows x 1 columns]
#      Sales
# 18    11.3
# 170    8.4
# 107   12.0
# 98    25.4
# 177   16.7
# 182    8.7
# ...

# %%
ML = LinearRegression()
ML.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_train_prediction=ML.predict(x_train)
print(x_train_prediction)
# Out:
# [[ 9.1709017 ]
#  [ 8.87695647]
#  [14.94093769]
#  [18.57170561]
#  [18.88742456]
#  [12.75267876]
#  [ 7.63041096]
#  [ 8.08221567]
#  [14.0046677 ]
#  [12.85610393]
#  [13.1391623 ]
#  [19.65494821]
#  [20.97770175]
#  [17.22717836]
#  [ 9.59548926]
#  [10.55353297]
#  [23.10608294]
#  [16.55219302]
#  [18.18522207]
#  [ 7.55964637]
#  [21.59825279]
#  [17.91849399]
#  [19.0561709 ]
#  [15.18044861]
#  [16.48687185]
#  [19.01262345]
#  [21.46216703]
#  [16.0622843 ]
#  [12.62747986]
#  [11.31561319]
#  [17.22717836]
#  [14.47280269]
#  [22.06094435]
#  [23.296603  ]
#  [12.39885579]
#  [13.1391623 ]
#  [21.06479663]
#  [18.27231695]
#  [20.23195181]
#  [17.70620021]
#  [17.56467103]
#  [12.04503283]
#  [ 9.50295094]
#  [ 9.24166629]
#  [ 7.87536532]
#  [20.18840437]
#  [ 8.09854596]
#  [18.63158334]
#  [ 8.55579409]
#  [16.79714737]
#  [18.424733  ]
#  [10.76038331]
#  [15.31109094]
#  [14.20607461]
#  [12.28998719]
#  [22.22424726]
#  [22.23513412]
#  [ 7.58686352]
# ...

# %%
print(y_train)
# Out:
#      Sales
# 134   10.8
# 66    11.0
# 26    15.0
# 113   20.9
# 168   17.1
# ..     ...
# 67    13.4
# 192    5.9
# 117    9.4
# 47    23.2
# 172    7.6
#
# [160 rows x 1 columns]

# %%
print(ML.coef_)
# Out:
# [[0.0544343]]

# %%
print(ML.intercept_)
# Out:
# [7.16227597]

# %%
x_test_prediction=ML.predict(x_train)
print(x_test_prediction)
# Out:
# [[ 9.1709017 ]
#  [ 8.87695647]
#  [14.94093769]
#  [18.57170561]
#  [18.88742456]
#  [12.75267876]
#  [ 7.63041096]
#  [ 8.08221567]
#  [14.0046677 ]
#  [12.85610393]
#  [13.1391623 ]
#  [19.65494821]
#  [20.97770175]
#  [17.22717836]
#  [ 9.59548926]
#  [10.55353297]
#  [23.10608294]
#  [16.55219302]
#  [18.18522207]
#  [ 7.55964637]
#  [21.59825279]
#  [17.91849399]
#  [19.0561709 ]
#  [15.18044861]
#  [16.48687185]
#  [19.01262345]
#  [21.46216703]
#  [16.0622843 ]
#  [12.62747986]
#  [11.31561319]
#  [17.22717836]
#  [14.47280269]
#  [22.06094435]
#  [23.296603  ]
#  [12.39885579]
#  [13.1391623 ]
#  [21.06479663]
#  [18.27231695]
#  [20.23195181]
#  [17.70620021]
#  [17.56467103]
#  [12.04503283]
#  [ 9.50295094]
#  [ 9.24166629]
#  [ 7.87536532]
#  [20.18840437]
#  [ 8.09854596]
#  [18.63158334]
#  [ 8.55579409]
#  [16.79714737]
#  [18.424733  ]
#  [10.76038331]
#  [15.31109094]
#  [14.20607461]
#  [12.28998719]
#  [22.22424726]
#  [22.23513412]
#  [ 7.58686352]
# ...

# %%
print(y_test)
# Out:
#      Sales
# 18    11.3
# 170    8.4
# 107   12.0
# 98    25.4
# 177   16.7
# 182    8.7
# 5      7.2
# 146   18.2
# 12     9.2
# 152   16.6
# 61    24.2
# 125   10.6
# 180   15.5
# 154   20.6
# 80    11.8
# 7     13.2
# 33    17.4
# 130    1.6
# 37    14.7
# 74    17.0
# 183   26.2
# 145   10.3
# 45    16.1
# 159   12.9
# 60     8.1
# 123   15.2
# 179   17.6
# 185   22.6
# 122   16.6
# 44     8.5
# 16    12.5
# 55    23.7
# 150   16.1
# 111   21.8
# 22     5.6
# 189    6.7
# 129    9.7
# 4     17.9
# 83    13.6
# 106    7.2

# %%
plt.figure(figsize=(9,6))
plt.scatter(y_train ,x_train_prediction)
plt.xlabel('original values')
plt.ylabel('predicted values')
plt.title("Orginal Values and Predicted Values")
# Out:
# Text(0.5, 1.0, 'Orginal Values and Predicted Values')

# %%
plt.figure(figsize=(7,5))
plt.scatter(y_train ,x_test_prediction)
plt.xlabel('original values')
plt.ylabel('predicted values')
plt.title("Orginal Values and Predicted Values")
# Out:
# Text(0.5, 1.0, 'Orginal Values and Predicted Values')
